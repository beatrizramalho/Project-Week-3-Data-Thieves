# %% [markdown]
# https://www.kaggle.com/mazenramadan/imdb-most-popular-films-and-series (Kaggle Database)
#
# https://www.rottentomatoes.com/top/bestofrt/ (Rotter tomates top 100 movies)

# %%
#import relevant libraries

import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

import collections
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Films Rotten Tomatoes

# %%
# get the films data from Rotten Tomatoes top 100 movies website

url = "https://www.rottentomatoes.com/top/bestofrt/"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, features = "lxml")
#print(soup.prettify())

# %%
movies = soup.find_all("table", {"class":"table"})
movies

data = []

for movie in movies:
    for row in movie.findAll('tr')[1:]:
        
        movie_names = row.findAll("a", {"class":"unstyled articleLink"})
        movie_name = movie_names[0].text.strip().capitalize()
        movie_name = movie_name[:len(movie_name) - 7]
        movie_name = re.sub('[^A-Za-z0-9 ]+', '', movie_name)
        
        movie_ratings = row.findAll("span", {"class":"tMeterScore"})
        movie_rating = movie_ratings[0].text
        movie_rating = re.sub('[^0-9 ]+', '', movie_rating)
        
        data.append({"Film name": movie_name, "Film Rating Rotten Tomatoes" : movie_rating})

#create the table with the relevant data from Rotten Tomatoes:
TopTomatoes = pd.DataFrame(data)
TopTomatoes["Film Rating Rotten Tomatoes"] = TopTomatoes["Film Rating Rotten Tomatoes"].apply(pd.to_numeric)
TopTomatoes
# Out:
#                                        Film name  Film Rating Rotten Tomatoes
# 0                          It happened one night                           99
# 1                                   Citizen kane                           99
# 2                               The wizard of oz                           98
# 3                                   Modern times                           98
# 4                                  Black panther                           96
# ..                                           ...                          ...
# 95  The battle of algiers la battaglia di algeri                           99
# 96                 Never rarely sometimes always                           99
# 97                                   Baby driver                           92
# 98                         The godfather part ii                           96
# 99                          Spiderman homecoming                           92
#
# [100 rows x 2 columns]

# %%
# Create the top 10 movies from Rotter Tomatoes

TopTomatoes = TopTomatoes.sort_values(by=["Film Rating Rotten Tomatoes"], ascending= False)
Top10Tomates = TopTomatoes.head(10)
Top10Tomates
# Out:
#                              Film name  Film Rating Rotten Tomatoes
# 48  Seven samurai shichinin no samurai                          100
# 73                             The kid                          100
# 65                      Leave no trace                          100
# 66                  The maltese falcon                          100
# 31                             Rebecca                          100
# 89                   Shadow of a doubt                          100
# 79                               Laura                          100
# 51                  Singin in the rain                          100
# 76        The adventures of robin hood                          100
# 23              The philadelphia story                          100

# %% [markdown]
# # Top Genres Rotten Tomatoes

# %%
# Extracting link for every movie from rotten tomatoes top 100
movie_url_list = []
for movie in movies:
    for row in movie.findAll('tr')[1:]:
        
        movie_link = row.a['href']
        movie_url = 'https://www.rottentomatoes.com' + row.a['href']
        movie_url_list.append(movie_url)
movie_url_list
# Out:
# ['https://www.rottentomatoes.com/m/it_happened_one_night',
#  'https://www.rottentomatoes.com/m/citizen_kane',
#  'https://www.rottentomatoes.com/m/the_wizard_of_oz_1939',
#  'https://www.rottentomatoes.com/m/modern_times',
#  'https://www.rottentomatoes.com/m/black_panther_2018',
#  'https://www.rottentomatoes.com/m/parasite_2019',
#  'https://www.rottentomatoes.com/m/avengers_endgame',
#  'https://www.rottentomatoes.com/m/1003707-casablanca',
#  'https://www.rottentomatoes.com/m/knives_out',
#  'https://www.rottentomatoes.com/m/us_2019',
#  'https://www.rottentomatoes.com/m/toy_story_4',
#  'https://www.rottentomatoes.com/m/lady_bird',
#  'https://www.rottentomatoes.com/m/mission_impossible_fallout',
#  'https://www.rottentomatoes.com/m/blackkklansman',
#  'https://www.rottentomatoes.com/m/get_out',
#  'https://www.rottentomatoes.com/m/the_irishman',
#  'https://www.rottentomatoes.com/m/godfather',
#  'https://www.rottentomatoes.com/m/mad_max_fury_road',
#  'https://www.rottentomatoes.com/m/spider_man_into_the_spider_verse',
#  'https://www.rottentomatoes.com/m/sunset_boulevard',
#  'https://www.rottentomatoes.com/m/moonlight_2016',
#  'https://www.rottentomatoes.com/m/1000626-all_about_eve',
#  'https://www.rottentomatoes.com/m/the_cabinet_of_dr_caligari',
#  'https://www.rottentomatoes.com/m/philadelphia_story',
#  'https://www.rottentomatoes.com/m/roma_2018',
#  'https://www.rottentomatoes.com/m/wonder_woman_2017',
#  'https://www.rottentomatoes.com/m/a_star_is_born_2018',
#  'https://www.rottentomatoes.com/m/inside_out_2015',
#  'https://www.rottentomatoes.com/m/a_quiet_place_2018',
#  'https://www.rottentomatoes.com/m/one_night_in_miami',
#  'https://www.rottentomatoes.com/m/eighth_grade',
#  'https://www.rottentomatoes.com/m/1017293-rebecca',
#  'https://www.rottentomatoes.com/m/logan_2017',
#  'https://www.rottentomatoes.com/m/booksmart',
#  'https://www.rottentomatoes.com/m/his_girl_friday',
#  'https://www.rottentomatoes.com/m/portrait_of_a_lady_on_fire',
#  'https://www.rottentomatoes.com/m/coco_2017',
#  'https://www.rottentomatoes.com/m/dunkirk_2017',
#  'https://www.rottentomatoes.com/m/star_wars_the_last_jedi',
#  'https://www.rottentomatoes.com/m/1015002-night_at_the_opera',
#  'https://www.rottentomatoes.com/m/the_shape_of_water_2017',
#  'https://www.rottentomatoes.com/m/thor_ragnarok_2017',
#  'https://www.rottentomatoes.com/m/spotlight_2015',
#  'https://www.rottentomatoes.com/m/the_farewell_2019',
#  'https://www.rottentomatoes.com/m/selma',
#  'https://www.rottentomatoes.com/m/the_third_man',
#  'https://www.rottentomatoes.com/m/1017289-rear_window',
#  'https://www.rottentomatoes.com/m/et_the_extraterrestrial',
#  'https://www.rottentomatoes.com/m/seven_samurai_1956',
#  'https://www.rottentomatoes.com/m/la_grande_illusion',
#  'https://www.rottentomatoes.com/m/arrival_2016',
#  'https://www.rottentomatoes.com/m/singin_in_the_rain',
#  'https://www.rottentomatoes.com/m/the_favourite_2018',
#  'https://www.rottentomatoes.com/m/double_indemnity',
#  'https://www.rottentomatoes.com/m/1000642-all_quiet_on_the_western_front',
#  'https://www.rottentomatoes.com/m/1048445-snow_white_and_the_seven_dwarfs',
#  'https://www.rottentomatoes.com/m/marriage_story_2019',
#  'https://www.rottentomatoes.com/m/the_big_sick',
#  'https://www.rottentomatoes.com/m/star_wars_episode_vii_the_force_awakens',
#  'https://www.rottentomatoes.com/m/american_in_paris',
#  'https://www.rottentomatoes.com/m/on_the_waterfront',
#  'https://www.rottentomatoes.com/m/best_years_of_our_lives',
#  'https://www.rottentomatoes.com/m/1013775-metropolis',
#  'https://www.rottentomatoes.com/m/boyhood',
#  'https://www.rottentomatoes.com/m/gravity_2013',
#  'https://www.rottentomatoes.com/m/leave_no_trace',
#  'https://www.rottentomatoes.com/m/1013139-maltese_falcon',
#  'https://www.rottentomatoes.com/m/the_invisible_man_2020',
#  'https://www.rottentomatoes.com/m/12_years_a_slave',
#  'https://www.rottentomatoes.com/m/once_upon_a_time_in_hollywood',
#  'https://www.rottentomatoes.com/m/argo_2012',
#  'https://www.rottentomatoes.com/m/soul_2020',
#  'https://www.rottentomatoes.com/m/ma_raineys_black_bottom',
#  'https://www.rottentomatoes.com/m/1052609-kid',
#  'https://www.rottentomatoes.com/m/manchester_by_the_sea',
#  'https://www.rottentomatoes.com/m/nosferatu',
#  'https://www.rottentomatoes.com/m/1000355-adventures_of_robin_hood',
#  'https://www.rottentomatoes.com/m/north-by-northwest',
#  'https://www.rottentomatoes.com/m/la_la_land',
#  'https://www.rottentomatoes.com/m/1012007-laura',
#  'https://www.rottentomatoes.com/m/spider_man_far_from_home',
#  'https://www.rottentomatoes.com/m/incredibles_2',
#  'https://www.rottentomatoes.com/m/zootopia',
#  'https://www.rottentomatoes.com/m/alien',
#  'https://www.rottentomatoes.com/m/1011615-king_kong',
#  'https://www.rottentomatoes.com/m/call_me_by_your_name',
#  'https://www.rottentomatoes.com/m/psycho',
#  'https://www.rottentomatoes.com/m/1917_2019',
#  'https://www.rottentomatoes.com/m/la_confidential',
#  'https://www.rottentomatoes.com/m/1018688-shadow_of_a_doubt',
#  'https://www.rottentomatoes.com/m/the_florida_project',
#  'https://www.rottentomatoes.com/m/war_for_the_planet_of_the_apes',
#  'https://www.rottentomatoes.com/m/paddington_2',
#  'https://www.rottentomatoes.com/m/beatles_a_hard_days_night',
#  'https://www.rottentomatoes.com/m/widows_2018',
#  'https://www.rottentomatoes.com/m/the_battle_of_algiers',
#  'https://www.rottentomatoes.com/m/never_rarely_sometimes_always',
#  'https://www.rottentomatoes.com/m/baby_driver',
#  'https://www.rottentomatoes.com/m/godfather_part_ii',
#  'https://www.rottentomatoes.com/m/spider_man_homecoming']

# %%
# Extracting genres of movies from rotten tomatoes top 100
rotten_genres = []
for link in movie_url_list:
    try:
        response = requests.get(link)
        soup = BeautifulSoup(response.content, features = 'lxml')
        # get the genre
        genre_link = soup.find_all('div', attrs = {'class': 'meta-value genre'})
        genre = genre_link[0].text.strip()
        genre = re.sub('[^A-Za-z0-9&,/ ]+', '', genre)
        genre = re.sub(' ', '', genre)
    
        # putting found genres into a list
        rotten_genres.append(genre)
    except:
        print(f'issue with this link - {link}')
print(rotten_genres)
# Out:
# ['Comedy,Romance', 'Drama', 'Fantasy,Kids&family,Musical', 'Comedy', 'Fantasy,Action,Adventure', 'Drama,Comedy,Mystery&thriller', 'Fantasy,Action,Adventure,Scifi', 'Drama', 'Drama,Crime,Comedy,Mystery&thriller', 'Horror,Mystery&thriller', 'Adventure,Animation,Fantasy,Kids&family,Comedy', 'Drama,Comedy', 'Action,Adventure,Mystery&thriller', 'Drama,Crime,Comedy', 'Comedy,Horror,Mystery&thriller', 'Drama,Crime', 'Drama,Crime', 'Action,Adventure', 'Animation,Fantasy,Action,Comedy,Kids&family,Adventure', 'Drama', 'Drama,Lgbtq', 'Drama', 'Fantasy,Horror,Mystery&thriller', 'Comedy,Romance', 'Drama', 'Action,Adventure,Fantasy', 'Drama,Music,Romance', 'Fantasy,Animation,Comedy,Kids&family', 'Horror,Mystery&thriller', 'Drama', 'Drama,Comedy', 'Mystery&thriller', 'Fantasy,Adventure,Action', 'Comedy,Lgbtq', 'Comedy', 'History,Drama,Romance,Lgbtq', 'Animation,Music,Comedy,Kids&family,Adventure', 'Drama,War,History', 'Fantasy,Action,Adventure,Scifi', 'Comedy', 'Fantasy,Romance', 'Fantasy,Action,Comedy,Adventure,Scifi', 'Drama', 'Drama,Comedy', 'History,Drama', 'Mystery&thriller', 'Mystery&thriller', 'Scifi,Adventure,Kids&family', 'Action', 'Drama,War', 'Drama,Scifi,Mystery&thriller', 'Comedy,Musical', 'Drama,Comedy', 'Drama,Crime', 'War', 'Fantasy,Animation,Kids&family', 'Drama,Comedy', 'Comedy,Romance', 'Fantasy,Action,Adventure,Scifi', 'Romance,Musical', 'Drama', 'Drama', 'Drama,Scifi', 'Drama', 'Drama,Scifi,Mystery&thriller', 'Drama', 'Drama,Crime', 'Horror,Mystery&thriller', 'History,Biography,Drama', 'Drama,Comedy', 'Drama,History,Mystery&thriller', 'Animation,Comedy,Kids&family,Adventure', 'Drama,Music,History', 'Drama,Comedy', 'Drama', 'Fantasy,Horror', 'Action,Adventure', 'Mystery&thriller', 'Drama,Comedy,Romance,Musical', 'Mystery&thriller', 'Fantasy,Action,Comedy,Adventure', 'Animation,Action,Comedy,Kids&family,Adventure', 'Animation,Comedy,Kids&family,Adventure', 'Horror,Scifi', 'Fantasy,Adventure', 'Drama,Romance,Lgbtq', 'Horror,Mystery&thriller', 'History,War,Drama', 'Drama,Crime', 'Drama,Crime,Mystery&thriller', 'Drama', 'Action,Adventure,Scifi', 'Comedy,Kids&family,Adventure', 'Comedy,Musical', 'Drama,Crime,Mystery&thriller', 'Drama,War,History', 'Drama', 'Action,Mystery&thriller', 'Drama,Crime', 'Fantasy,Action,Comedy,Adventure']

# %%
# We received list with multiple genres for each movie, trying to clean it better
rot_gen = []
for item in rotten_genres:
    item = item.split(',')
    rot_gen.append(item)
print(rot_gen)
# Out:
# [['Comedy', 'Romance'], ['Drama'], ['Fantasy', 'Kids&family', 'Musical'], ['Comedy'], ['Fantasy', 'Action', 'Adventure'], ['Drama', 'Comedy', 'Mystery&thriller'], ['Fantasy', 'Action', 'Adventure', 'Scifi'], ['Drama'], ['Drama', 'Crime', 'Comedy', 'Mystery&thriller'], ['Horror', 'Mystery&thriller'], ['Adventure', 'Animation', 'Fantasy', 'Kids&family', 'Comedy'], ['Drama', 'Comedy'], ['Action', 'Adventure', 'Mystery&thriller'], ['Drama', 'Crime', 'Comedy'], ['Comedy', 'Horror', 'Mystery&thriller'], ['Drama', 'Crime'], ['Drama', 'Crime'], ['Action', 'Adventure'], ['Animation', 'Fantasy', 'Action', 'Comedy', 'Kids&family', 'Adventure'], ['Drama'], ['Drama', 'Lgbtq'], ['Drama'], ['Fantasy', 'Horror', 'Mystery&thriller'], ['Comedy', 'Romance'], ['Drama'], ['Action', 'Adventure', 'Fantasy'], ['Drama', 'Music', 'Romance'], ['Fantasy', 'Animation', 'Comedy', 'Kids&family'], ['Horror', 'Mystery&thriller'], ['Drama'], ['Drama', 'Comedy'], ['Mystery&thriller'], ['Fantasy', 'Adventure', 'Action'], ['Comedy', 'Lgbtq'], ['Comedy'], ['History', 'Drama', 'Romance', 'Lgbtq'], ['Animation', 'Music', 'Comedy', 'Kids&family', 'Adventure'], ['Drama', 'War', 'History'], ['Fantasy', 'Action', 'Adventure', 'Scifi'], ['Comedy'], ['Fantasy', 'Romance'], ['Fantasy', 'Action', 'Comedy', 'Adventure', 'Scifi'], ['Drama'], ['Drama', 'Comedy'], ['History', 'Drama'], ['Mystery&thriller'], ['Mystery&thriller'], ['Scifi', 'Adventure', 'Kids&family'], ['Action'], ['Drama', 'War'], ['Drama', 'Scifi', 'Mystery&thriller'], ['Comedy', 'Musical'], ['Drama', 'Comedy'], ['Drama', 'Crime'], ['War'], ['Fantasy', 'Animation', 'Kids&family'], ['Drama', 'Comedy'], ['Comedy', 'Romance'], ['Fantasy', 'Action', 'Adventure', 'Scifi'], ['Romance', 'Musical'], ['Drama'], ['Drama'], ['Drama', 'Scifi'], ['Drama'], ['Drama', 'Scifi', 'Mystery&thriller'], ['Drama'], ['Drama', 'Crime'], ['Horror', 'Mystery&thriller'], ['History', 'Biography', 'Drama'], ['Drama', 'Comedy'], ['Drama', 'History', 'Mystery&thriller'], ['Animation', 'Comedy', 'Kids&family', 'Adventure'], ['Drama', 'Music', 'History'], ['Drama', 'Comedy'], ['Drama'], ['Fantasy', 'Horror'], ['Action', 'Adventure'], ['Mystery&thriller'], ['Drama', 'Comedy', 'Romance', 'Musical'], ['Mystery&thriller'], ['Fantasy', 'Action', 'Comedy', 'Adventure'], ['Animation', 'Action', 'Comedy', 'Kids&family', 'Adventure'], ['Animation', 'Comedy', 'Kids&family', 'Adventure'], ['Horror', 'Scifi'], ['Fantasy', 'Adventure'], ['Drama', 'Romance', 'Lgbtq'], ['Horror', 'Mystery&thriller'], ['History', 'War', 'Drama'], ['Drama', 'Crime'], ['Drama', 'Crime', 'Mystery&thriller'], ['Drama'], ['Action', 'Adventure', 'Scifi'], ['Comedy', 'Kids&family', 'Adventure'], ['Comedy', 'Musical'], ['Drama', 'Crime', 'Mystery&thriller'], ['Drama', 'War', 'History'], ['Drama'], ['Action', 'Mystery&thriller'], ['Drama', 'Crime'], ['Fantasy', 'Action', 'Comedy', 'Adventure']]

# %%
r_g = []
for string in rot_gen:
    for word in string:
        word = word.split(',')
        #word = word.split('&')
        r_g.append(word)
print(r_g)
# Out:
# [['Comedy'], ['Romance'], ['Drama'], ['Fantasy'], ['Kids&family'], ['Musical'], ['Comedy'], ['Fantasy'], ['Action'], ['Adventure'], ['Drama'], ['Comedy'], ['Mystery&thriller'], ['Fantasy'], ['Action'], ['Adventure'], ['Scifi'], ['Drama'], ['Drama'], ['Crime'], ['Comedy'], ['Mystery&thriller'], ['Horror'], ['Mystery&thriller'], ['Adventure'], ['Animation'], ['Fantasy'], ['Kids&family'], ['Comedy'], ['Drama'], ['Comedy'], ['Action'], ['Adventure'], ['Mystery&thriller'], ['Drama'], ['Crime'], ['Comedy'], ['Comedy'], ['Horror'], ['Mystery&thriller'], ['Drama'], ['Crime'], ['Drama'], ['Crime'], ['Action'], ['Adventure'], ['Animation'], ['Fantasy'], ['Action'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Drama'], ['Drama'], ['Lgbtq'], ['Drama'], ['Fantasy'], ['Horror'], ['Mystery&thriller'], ['Comedy'], ['Romance'], ['Drama'], ['Action'], ['Adventure'], ['Fantasy'], ['Drama'], ['Music'], ['Romance'], ['Fantasy'], ['Animation'], ['Comedy'], ['Kids&family'], ['Horror'], ['Mystery&thriller'], ['Drama'], ['Drama'], ['Comedy'], ['Mystery&thriller'], ['Fantasy'], ['Adventure'], ['Action'], ['Comedy'], ['Lgbtq'], ['Comedy'], ['History'], ['Drama'], ['Romance'], ['Lgbtq'], ['Animation'], ['Music'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Drama'], ['War'], ['History'], ['Fantasy'], ['Action'], ['Adventure'], ['Scifi'], ['Comedy'], ['Fantasy'], ['Romance'], ['Fantasy'], ['Action'], ['Comedy'], ['Adventure'], ['Scifi'], ['Drama'], ['Drama'], ['Comedy'], ['History'], ['Drama'], ['Mystery&thriller'], ['Mystery&thriller'], ['Scifi'], ['Adventure'], ['Kids&family'], ['Action'], ['Drama'], ['War'], ['Drama'], ['Scifi'], ['Mystery&thriller'], ['Comedy'], ['Musical'], ['Drama'], ['Comedy'], ['Drama'], ['Crime'], ['War'], ['Fantasy'], ['Animation'], ['Kids&family'], ['Drama'], ['Comedy'], ['Comedy'], ['Romance'], ['Fantasy'], ['Action'], ['Adventure'], ['Scifi'], ['Romance'], ['Musical'], ['Drama'], ['Drama'], ['Drama'], ['Scifi'], ['Drama'], ['Drama'], ['Scifi'], ['Mystery&thriller'], ['Drama'], ['Drama'], ['Crime'], ['Horror'], ['Mystery&thriller'], ['History'], ['Biography'], ['Drama'], ['Drama'], ['Comedy'], ['Drama'], ['History'], ['Mystery&thriller'], ['Animation'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Drama'], ['Music'], ['History'], ['Drama'], ['Comedy'], ['Drama'], ['Fantasy'], ['Horror'], ['Action'], ['Adventure'], ['Mystery&thriller'], ['Drama'], ['Comedy'], ['Romance'], ['Musical'], ['Mystery&thriller'], ['Fantasy'], ['Action'], ['Comedy'], ['Adventure'], ['Animation'], ['Action'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Animation'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Horror'], ['Scifi'], ['Fantasy'], ['Adventure'], ['Drama'], ['Romance'], ['Lgbtq'], ['Horror'], ['Mystery&thriller'], ['History'], ['War'], ['Drama'], ['Drama'], ['Crime'], ['Drama'], ['Crime'], ['Mystery&thriller'], ['Drama'], ['Action'], ['Adventure'], ['Scifi'], ['Comedy'], ['Kids&family'], ['Adventure'], ['Comedy'], ['Musical'], ['Drama'], ['Crime'], ['Mystery&thriller'], ['Drama'], ['War'], ['History'], ['Drama'], ['Action'], ['Mystery&thriller'], ['Drama'], ['Crime'], ['Fantasy'], ['Action'], ['Comedy'], ['Adventure']]

# %%
# Finally a list with genres from rotten tomatoes
rg = [i for element in r_g for i in element]
print(rg)
# Out:
# ['Comedy', 'Romance', 'Drama', 'Fantasy', 'Kids&family', 'Musical', 'Comedy', 'Fantasy', 'Action', 'Adventure', 'Drama', 'Comedy', 'Mystery&thriller', 'Fantasy', 'Action', 'Adventure', 'Scifi', 'Drama', 'Drama', 'Crime', 'Comedy', 'Mystery&thriller', 'Horror', 'Mystery&thriller', 'Adventure', 'Animation', 'Fantasy', 'Kids&family', 'Comedy', 'Drama', 'Comedy', 'Action', 'Adventure', 'Mystery&thriller', 'Drama', 'Crime', 'Comedy', 'Comedy', 'Horror', 'Mystery&thriller', 'Drama', 'Crime', 'Drama', 'Crime', 'Action', 'Adventure', 'Animation', 'Fantasy', 'Action', 'Comedy', 'Kids&family', 'Adventure', 'Drama', 'Drama', 'Lgbtq', 'Drama', 'Fantasy', 'Horror', 'Mystery&thriller', 'Comedy', 'Romance', 'Drama', 'Action', 'Adventure', 'Fantasy', 'Drama', 'Music', 'Romance', 'Fantasy', 'Animation', 'Comedy', 'Kids&family', 'Horror', 'Mystery&thriller', 'Drama', 'Drama', 'Comedy', 'Mystery&thriller', 'Fantasy', 'Adventure', 'Action', 'Comedy', 'Lgbtq', 'Comedy', 'History', 'Drama', 'Romance', 'Lgbtq', 'Animation', 'Music', 'Comedy', 'Kids&family', 'Adventure', 'Drama', 'War', 'History', 'Fantasy', 'Action', 'Adventure', 'Scifi', 'Comedy', 'Fantasy', 'Romance', 'Fantasy', 'Action', 'Comedy', 'Adventure', 'Scifi', 'Drama', 'Drama', 'Comedy', 'History', 'Drama', 'Mystery&thriller', 'Mystery&thriller', 'Scifi', 'Adventure', 'Kids&family', 'Action', 'Drama', 'War', 'Drama', 'Scifi', 'Mystery&thriller', 'Comedy', 'Musical', 'Drama', 'Comedy', 'Drama', 'Crime', 'War', 'Fantasy', 'Animation', 'Kids&family', 'Drama', 'Comedy', 'Comedy', 'Romance', 'Fantasy', 'Action', 'Adventure', 'Scifi', 'Romance', 'Musical', 'Drama', 'Drama', 'Drama', 'Scifi', 'Drama', 'Drama', 'Scifi', 'Mystery&thriller', 'Drama', 'Drama', 'Crime', 'Horror', 'Mystery&thriller', 'History', 'Biography', 'Drama', 'Drama', 'Comedy', 'Drama', 'History', 'Mystery&thriller', 'Animation', 'Comedy', 'Kids&family', 'Adventure', 'Drama', 'Music', 'History', 'Drama', 'Comedy', 'Drama', 'Fantasy', 'Horror', 'Action', 'Adventure', 'Mystery&thriller', 'Drama', 'Comedy', 'Romance', 'Musical', 'Mystery&thriller', 'Fantasy', 'Action', 'Comedy', 'Adventure', 'Animation', 'Action', 'Comedy', 'Kids&family', 'Adventure', 'Animation', 'Comedy', 'Kids&family', 'Adventure', 'Horror', 'Scifi', 'Fantasy', 'Adventure', 'Drama', 'Romance', 'Lgbtq', 'Horror', 'Mystery&thriller', 'History', 'War', 'Drama', 'Drama', 'Crime', 'Drama', 'Crime', 'Mystery&thriller', 'Drama', 'Action', 'Adventure', 'Scifi', 'Comedy', 'Kids&family', 'Adventure', 'Comedy', 'Musical', 'Drama', 'Crime', 'Mystery&thriller', 'Drama', 'War', 'History', 'Drama', 'Action', 'Mystery&thriller', 'Drama', 'Crime', 'Fantasy', 'Action', 'Comedy', 'Adventure']

# %%
# Creating a dictionary with frequency of each genre in rotten tomatoes top 100
genre_freq={}
for word in rg:
    if word in genre_freq:
        genre_freq[word]+=1
    else:
        genre_freq[word]=1
print(genre_freq)
# Out:
# {'Comedy': 32, 'Romance': 9, 'Drama': 48, 'Fantasy': 18, 'Kids&family': 11, 'Musical': 5, 'Action': 17, 'Adventure': 22, 'Mystery&thriller': 20, 'Scifi': 10, 'Crime': 10, 'Horror': 8, 'Animation': 8, 'Lgbtq': 4, 'Music': 3, 'History': 8, 'War': 5, 'Biography': 1}

# %%
# Here we have a dataframe to visualize genres

data_items = genre_freq.items()
data_list = list(data_items)

rottentotomatoes_genres = pd.DataFrame(data_list, columns = ['Genre', 'Popularity'])
rottentotomatoes_genres
# Out:
#                Genre  Popularity
# 0             Comedy          32
# 1            Romance           9
# 2              Drama          48
# 3            Fantasy          18
# 4        Kids&family          11
# 5            Musical           5
# 6             Action          17
# 7          Adventure          22
# 8   Mystery&thriller          20
# 9              Scifi          10
# 10             Crime          10
# 11            Horror           8
# 12         Animation           8
# 13             Lgbtq           4
# 14             Music           3
# 15           History           8
# 16               War           5
# 17         Biography           1

# %%
# Our goal to see top 3 genres what critics choose

rottentotomatoes_genres = rottentotomatoes_genres.sort_values(by=['Popularity'], ascending=False)
rottentotomatoes_genres = rottentotomatoes_genres.head(3)
rottentotomatoes_genres
# Out:
#        Genre  Popularity
# 2      Drama          48
# 0     Comedy          32
# 7  Adventure          22

# %%
# Moving column Genre as an index for better vizualization on chart

rottentotomatoes_genres = rottentotomatoes_genres.set_index('Genre')

# %%
# Chart of Top 3 genres on Rotten Tomatoes

rottentotomatoes_genres.plot(kind='bar')
plt.title('Top 3 genres on Rotten Tomatoes', color = 'red', size = '20')
plt.xticks(rotation=0)
plt.ylabel('Popularity')
plt.show()

# %% [markdown]
# # Working on the IMDB data

# %%
#IMDM datasource
imdb = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Final Project - Module 1\\Project-Week-3-Data-Thieves\\your-project\\imdb.csv")
imdb
# Out:
#                                         Name  Date Rate    Votes  \
# 0                             No Time to Die  2021  7.6  107,163
# 1                                 The Guilty  2021  6.3   64,375
# 2                  The Many Saints of Newark  2021  6.4   27,145
# 3                Venom: Let There Be Carnage  2021  6.4   30,443
# 4                                       Dune  2021  8.3   84,636
# ...                                      ...   ...  ...      ...
# 6173  The Human Centipede II (Full Sequence)  2011  3.8   37,492
# 6174                        Double Indemnity  1944  8.3  150,448
# 6175      Before the Devil Knows You're Dead  2007  7.3  100,668
# 6176                              Queen Bees  2021  6.0      887
# 6177                              Death Race  2008  6.3  203,578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 6173                       Horror      91   Film   Not Rated        -
# 6174      Crime, Drama, Film-Noir     107   Film      Passed        -
# 6175       Crime, Drama, Thriller     117   Film           R        -
# 6176       Comedy, Drama, Romance     100   Film       PG-13        -
# 6177     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 6173    Severe    Severe    Severe      Mild      Severe
# 6174      None      Mild      None      Mild        Mild
# 6175    Severe  Moderate    Severe    Severe      Severe
# 6176      None      None      Mild  Moderate        None
# 6177      Mild    Severe    Severe      Mild    Moderate
#
# [6178 rows x 14 columns]

# %%
#IMDB data cleaning
imdb = imdb.drop_duplicates(subset=['Name'])
imdb = imdb[imdb["Type"] == "Film"]
imdb = imdb[imdb["Rate"] != "No Rate"]
imdb
# Out:
#                                         Name  Date Rate    Votes  \
# 0                             No Time to Die  2021  7.6  107,163
# 1                                 The Guilty  2021  6.3   64,375
# 2                  The Many Saints of Newark  2021  6.4   27,145
# 3                Venom: Let There Be Carnage  2021  6.4   30,443
# 4                                       Dune  2021  8.3   84,636
# ...                                      ...   ...  ...      ...
# 5023  The Human Centipede II (Full Sequence)  2011  3.8   37,492
# 5024                        Double Indemnity  1944  8.3  150,448
# 5025      Before the Devil Knows You're Dead  2007  7.3  100,668
# 5026                              Queen Bees  2021  6.0      887
# 5027                              Death Race  2008  6.3  203,578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 5023                       Horror      91   Film   Not Rated        -
# 5024      Crime, Drama, Film-Noir     107   Film      Passed        -
# 5025       Crime, Drama, Thriller     117   Film           R        -
# 5026       Comedy, Drama, Romance     100   Film       PG-13        -
# 5027     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 5023    Severe    Severe    Severe      Mild      Severe
# 5024      None      Mild      None      Mild        Mild
# 5025    Severe  Moderate    Severe    Severe      Severe
# 5026      None      None      Mild  Moderate        None
# 5027      Mild    Severe    Severe      Mild    Moderate
#
# [3316 rows x 14 columns]

# %%
#imdb.info() - Verify that both columns Values and Rates were objects

imdb.Votes = imdb.Votes.str.replace(",", "") #to replace the comma in the Votes column

imdb[["Votes", "Rate"]] = imdb[["Votes", "Rate"]].apply(pd.to_numeric) #change the type of the both columns
imdb
# Out:
#                                         Name  Date  Rate   Votes  \
# 0                             No Time to Die  2021   7.6  107163
# 1                                 The Guilty  2021   6.3   64375
# 2                  The Many Saints of Newark  2021   6.4   27145
# 3                Venom: Let There Be Carnage  2021   6.4   30443
# 4                                       Dune  2021   8.3   84636
# ...                                      ...   ...   ...     ...
# 5023  The Human Centipede II (Full Sequence)  2011   3.8   37492
# 5024                        Double Indemnity  1944   8.3  150448
# 5025      Before the Devil Knows You're Dead  2007   7.3  100668
# 5026                              Queen Bees  2021   6.0     887
# 5027                              Death Race  2008   6.3  203578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 5023                       Horror      91   Film   Not Rated        -
# 5024      Crime, Drama, Film-Noir     107   Film      Passed        -
# 5025       Crime, Drama, Thriller     117   Film           R        -
# 5026       Comedy, Drama, Romance     100   Film       PG-13        -
# 5027     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 5023    Severe    Severe    Severe      Mild      Severe
# 5024      None      Mild      None      Mild        Mild
# 5025    Severe  Moderate    Severe    Severe      Severe
# 5026      None      None      Mild  Moderate        None
# 5027      Mild    Severe    Severe      Mild    Moderate
#
# [3316 rows x 14 columns]

# %%
#IMDB follow a rule that movies only count for the tops if they have more 25 thousand
imdb = imdb[imdb["Votes"] >= 25000]
imdb
# Out:
#                                         Name  Date  Rate   Votes  \
# 0                             No Time to Die  2021   7.6  107163
# 1                                 The Guilty  2021   6.3   64375
# 2                  The Many Saints of Newark  2021   6.4   27145
# 3                Venom: Let There Be Carnage  2021   6.4   30443
# 4                                       Dune  2021   8.3   84636
# ...                                      ...   ...   ...     ...
# 5021                              Chugyeokja  2008   7.8   62423
# 5023  The Human Centipede II (Full Sequence)  2011   3.8   37492
# 5024                        Double Indemnity  1944   8.3  150448
# 5025      Before the Devil Knows You're Dead  2007   7.3  100668
# 5027                              Death Race  2008   6.3  203578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 5021      Action, Crime, Thriller     125   Film   Not Rated        -
# 5023                       Horror      91   Film   Not Rated        -
# 5024      Crime, Drama, Film-Noir     107   Film      Passed        -
# 5025       Crime, Drama, Thriller     117   Film           R        -
# 5027     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 5021      Mild    Severe  Moderate      Mild      Severe
# 5023    Severe    Severe    Severe      Mild      Severe
# 5024      None      Mild      None      Mild        Mild
# 5025    Severe  Moderate    Severe    Severe      Severe
# 5027      Mild    Severe    Severe      Mild    Moderate
#
# [2658 rows x 14 columns]

# %%
#appy regex to the film name to clean it as match 
imdb["Name"] = imdb["Name"].str.replace(r'[^A-Za-z0-9 ]+', "")
imdb
# Out:
# C:\Users\beatr\AppData\Local\Temp/ipykernel_18344/907555227.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   imdb["Name"] = imdb["Name"].str.replace(r'[^A-Za-z0-9 ]+', "")
# C:\Users\beatr\AppData\Local\Temp/ipykernel_18344/907555227.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb["Name"] = imdb["Name"].str.replace(r'[^A-Za-z0-9 ]+', "")
#                                       Name  Date  Rate   Votes  \
# 0                           No Time to Die  2021   7.6  107163
# 1                               The Guilty  2021   6.3   64375
# 2                The Many Saints of Newark  2021   6.4   27145
# 3               Venom Let There Be Carnage  2021   6.4   30443
# 4                                     Dune  2021   8.3   84636
# ...                                    ...   ...   ...     ...
# 5021                            Chugyeokja  2008   7.8   62423
# 5023  The Human Centipede II Full Sequence  2011   3.8   37492
# 5024                      Double Indemnity  1944   8.3  150448
# 5025     Before the Devil Knows Youre Dead  2007   7.3  100668
# 5027                            Death Race  2008   6.3  203578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 5021      Action, Crime, Thriller     125   Film   Not Rated        -
# 5023                       Horror      91   Film   Not Rated        -
# 5024      Crime, Drama, Film-Noir     107   Film      Passed        -
# 5025       Crime, Drama, Thriller     117   Film           R        -
# 5027     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 5021      Mild    Severe  Moderate      Mild      Severe
# 5023    Severe    Severe    Severe      Mild      Severe
# 5024      None      Mild      None      Mild        Mild
# 5025    Severe  Moderate    Severe    Severe      Severe
# 5027      Mild    Severe    Severe      Mild    Moderate
#
# [2658 rows x 14 columns]

# %% [markdown]
# # Films IMDB

# %%
#Create a new data set with only the necessary columns

new_imdb = imdb[["Name", "Rate", "Genre", "Certificate"]]
new_imdb
# Out:
#                                       Name  Rate                        Genre  \
# 0                           No Time to Die   7.6  Action, Adventure, Thriller
# 1                               The Guilty   6.3       Crime, Drama, Thriller
# 2                The Many Saints of Newark   6.4                 Crime, Drama
# 3               Venom Let There Be Carnage   6.4    Action, Adventure, Sci-Fi
# 4                                     Dune   8.3     Action, Adventure, Drama
# ...                                    ...   ...                          ...
# 5021                            Chugyeokja   7.8      Action, Crime, Thriller
# 5023  The Human Centipede II Full Sequence   3.8                       Horror
# 5024                      Double Indemnity   8.3      Crime, Drama, Film-Noir
# 5025     Before the Devil Knows Youre Dead   7.3       Crime, Drama, Thriller
# 5027                            Death Race   6.3     Action, Sci-Fi, Thriller
#
#      Certificate
# 0          PG-13
# 1              R
# 2              R
# 3          PG-13
# 4          PG-13
# ...          ...
# 5021   Not Rated
# 5023   Not Rated
# 5024      Passed
# 5025           R
# 5027           R
#
# [2658 rows x 4 columns]

# %%
#Replace those movies write wrong names
new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Gisaengchung", value ="Parasite Gisaengchung")
new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Shichinin no samurai", value ="Seven Samurai Shichinin no Samurai")
new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Sunset Blvd", value ="Sunset Boulevard")
new_imdb

#new_imdb.to_excel("new_imdb.xlsx")
# Out:
# C:\Users\beatr\AppData\Local\Temp/ipykernel_18344/2330577059.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Gisaengchung", value ="Parasite Gisaengchung")
# C:\Users\beatr\AppData\Local\Temp/ipykernel_18344/2330577059.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Shichinin no samurai", value ="Seven Samurai Shichinin no Samurai")
# C:\Users\beatr\AppData\Local\Temp/ipykernel_18344/2330577059.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_imdb["Name"] = new_imdb["Name"].replace(to_replace ="Sunset Blvd", value ="Sunset Boulevard")
#                                       Name  Rate                        Genre  \
# 0                           No Time to Die   7.6  Action, Adventure, Thriller
# 1                               The Guilty   6.3       Crime, Drama, Thriller
# 2                The Many Saints of Newark   6.4                 Crime, Drama
# 3               Venom Let There Be Carnage   6.4    Action, Adventure, Sci-Fi
# 4                                     Dune   8.3     Action, Adventure, Drama
# ...                                    ...   ...                          ...
# 5021                            Chugyeokja   7.8      Action, Crime, Thriller
# 5023  The Human Centipede II Full Sequence   3.8                       Horror
# 5024                      Double Indemnity   8.3      Crime, Drama, Film-Noir
# 5025     Before the Devil Knows Youre Dead   7.3       Crime, Drama, Thriller
# 5027                            Death Race   6.3     Action, Sci-Fi, Thriller
#
#      Certificate
# 0          PG-13
# 1              R
# 2              R
# 3          PG-13
# 4          PG-13
# ...          ...
# 5021   Not Rated
# 5023   Not Rated
# 5024      Passed
# 5025           R
# 5027           R
#
# [2658 rows x 4 columns]

# %%
# Add the sorts so that we can extract the ones that we want
new_imdb = new_imdb.sort_values(by=["Rate",'Name'], ascending=False)
new_imdb['Name'] = new_imdb['Name'].str.capitalize() #change the name columns for better match with RT data

# %%
#Creating our own IMDB top 100 

TopImdb = new_imdb.head(100)

TopImdb = TopImdb.rename(columns={"Name": "Film name", "Rate": "Film Rating IMDB", "Genre": "Genre"})
TopImdb

#TopImdb.to_excel("TopImdb.xlsx")
# Out:
#                               Film name  Film Rating IMDB  \
# 201            The shawshank redemption               9.3
# 251                       The godfather               9.2
# 929               The godfather part ii               9.0
# 270                     The dark knight               9.0
# 839                        12 angry men               9.0
# ...                                 ...               ...
# 1627  Le fabuleux destin damlie poulain               8.3
# 2572                 Lawrence of arabia               8.3
# 1156   Kimetsu no yaiba mugen resshahen               8.3
# 4700            Jodaeiye nader az simin               8.3
# 1187                             Jagten               8.3
#
#                              Genre Certificate
# 201                          Drama           R
# 251                   Crime, Drama           R
# 929                   Crime, Drama           R
# 270           Action, Crime, Drama       PG-13
# 839                   Crime, Drama    Approved
# ...                            ...         ...
# 1627               Comedy, Romance           R
# 2572   Adventure, Biography, Drama    Approved
# 1156  Animation, Action, Adventure        None
# 4700                         Drama       PG-13
# 1187                         Drama           R
#
# [100 rows x 4 columns]

# %% [markdown]
# # Top of the tops

# %%
#Inner Join - merge the two top 100 to get the movies in both tops:
Bothrakings = pd.merge(TopImdb, TopTomatoes, left_on='Film name', right_on='Film name')
Bothrakings.head(100)

#Conclusion:
#the critics and the viewers have different movies tastes as we found only 15 movies matching both the two top 100 movies
# Out:
#                              Film name  Film Rating IMDB  \
# 0                        The godfather               9.2
# 1                The godfather part ii               9.0
# 2   Seven samurai shichinin no samurai               8.6
# 3                Parasite gisaengchung               8.6
# 4                          Rear window               8.5
# 5                               Psycho               8.5
# 6                           Casablanca               8.5
# 7                     Sunset boulevard               8.4
# 8       Spiderman into the spiderverse               8.4
# 9                                 Coco               8.4
# 10                    Avengers endgame               8.4
# 11                               Alien               8.4
# 12                  Singin in the rain               8.3
# 13                  North by northwest               8.3
# 14                          Metropolis               8.3
#
#                            Genre Certificate  Film Rating Rotten Tomatoes
# 0                   Crime, Drama           R                           97
# 1                   Crime, Drama           R                           96
# 2       Action, Adventure, Drama   Not Rated                          100
# 3        Comedy, Drama, Thriller           R                           98
# 4              Mystery, Thriller          PG                           98
# 5      Horror, Mystery, Thriller           R                           96
# 6            Drama, Romance, War          PG                           99
# 7               Drama, Film-Noir      Passed                           98
# 8   Animation, Action, Adventure          PG                           97
# 9   Animation, Adventure, Comedy          PG                           97
# 10      Action, Adventure, Drama       PG-13                           94
# 11                Horror, Sci-Fi           R                           98
# 12      Comedy, Musical, Romance           G                          100
# 13  Adventure, Mystery, Thriller    Approved                           97
# 14                 Drama, Sci-Fi   Not Rated                           97

# %%
#Creating our own IMDB top 10

Top10Imdb = new_imdb.head(10)
Top10Imdb
# Out:
#                                                  Name  Rate  \
# 201                          The shawshank redemption   9.3
# 251                                     The godfather   9.2
# 929                             The godfather part ii   9.0
# 270                                   The dark knight   9.0
# 839                                      12 angry men   9.0
# 816      The lord of the rings the return of the king   8.9
# 555                                   Schindlers list   8.9
# 320                                      Pulp fiction   8.9
# 341  The lord of the rings the fellowship of the ring   8.8
# 318                                         Inception   8.8
#
#                          Genre Certificate
# 201                      Drama           R
# 251               Crime, Drama           R
# 929               Crime, Drama           R
# 270       Action, Crime, Drama       PG-13
# 839               Crime, Drama    Approved
# 816   Action, Adventure, Drama       PG-13
# 555  Biography, Drama, History           R
# 320               Crime, Drama           R
# 341   Action, Adventure, Drama       PG-13
# 318  Action, Adventure, Sci-Fi       PG-13

# %% [markdown]
# # Top Genres of IMDB

# %%
#TopImdb["Genre"] = TopImdb["Genre"].apply(lambda x: list(x.split(",")))

TopImdb["Genre"]

list_genres_imdb =[] 

for item in TopImdb["Genre"]:
    list_genres_imdb.append(item)

list_new = []

for element in list_genres_imdb:
    #print(type(element))
    element = element.split(",")
    #print(element)
    list_new.append(element)
    
list_newnew = [word.upper().strip() for element in list_new for word in element]

#get the list with all genres and separe them for 1 item in the list being one genre
print(list_newnew)
# Out:
# ['DRAMA', 'CRIME', 'DRAMA', 'CRIME', 'DRAMA', 'ACTION', 'CRIME', 'DRAMA', 'CRIME', 'DRAMA', 'ACTION', 'ADVENTURE', 'DRAMA', 'BIOGRAPHY', 'DRAMA', 'HISTORY', 'CRIME', 'DRAMA', 'ACTION', 'ADVENTURE', 'DRAMA', 'ACTION', 'ADVENTURE', 'SCI-FI', 'WESTERN', 'DRAMA', 'ROMANCE', 'DRAMA', 'ACTION', 'SCI-FI', 'ACTION', 'ADVENTURE', 'DRAMA', 'ACTION', 'ADVENTURE', 'FANTASY', 'ACTION', 'BIOGRAPHY', 'DRAMA', 'DRAMA', 'BIOGRAPHY', 'CRIME', 'DRAMA', 'COMEDY', 'DRAMA', 'MUSIC', 'CRIME', 'DRAMA', 'THRILLER', 'CRIME', 'DRAMA', 'FANTASY', 'ACTION', 'ADVENTURE', 'FANTASY', 'ACTION', 'ADVENTURE', 'DRAMA', 'ACTION', 'DRAMA', 'MYSTERY', 'ANIMATION', 'ADVENTURE', 'FAMILY', 'CRIME', 'DRAMA', 'MYSTERY', 'DRAMA', 'WAR', 'COMEDY', 'DRAMA', 'THRILLER', 'COMEDY', 'DRAMA', 'ROMANCE', 'DRAMA', 'FAMILY', 'FANTASY', 'ADVENTURE', 'DRAMA', 'SCI-FI', 'CRIME', 'DRAMA', 'DRAMA', 'MUSIC', 'CRIME', 'MYSTERY', 'THRILLER', 'DRAMA', 'MYSTERY', 'SCI-FI', 'BIOGRAPHY', 'DRAMA', 'MUSIC', 'ANIMATION', 'ADVENTURE', 'DRAMA', 'BIOGRAPHY', 'COMEDY', 'DRAMA', 'CRIME', 'DRAMA', 'THRILLER', 'ACTION', 'SCI-FI', 'MYSTERY', 'THRILLER', 'HORROR', 'MYSTERY', 'THRILLER', 'WESTERN', 'DRAMA', 'ROMANCE', 'ACTION', 'CRIME', 'DRAMA', 'ANIMATION', 'DRAMA', 'WAR', 'ACTION', 'ADVENTURE', 'DRAMA', 'DRAMA', 'ROMANCE', 'WAR', 'ADVENTURE', 'COMEDY', 'SCI-FI', 'DRAMA', 'CRIME', 'DRAMA', 'MYSTERY', 'ANIMATION', 'ADVENTURE', 'FAMILY', 'DRAMA', 'HORROR', 'DRAMA', 'MYSTERY', 'THRILLER', 'ACTION', 'DRAMA', 'FILM-NOIR', 'ANIMATION', 'ACTION', 'ADVENTURE', 'ACTION', 'CRIME', 'DRAMA', 'ACTION', 'ADVENTURE', 'DRAMA', 'WAR', 'ACTION', 'DRAMA', 'MYSTERY', 'ANIMATION', 'ACTION', 'ADVENTURE', 'MYSTERY', 'THRILLER', 'ANIMATION', 'DRAMA', 'FANTASY', 'CRIME', 'DRAMA', 'THRILLER', 'BIOGRAPHY', 'DRAMA', 'HISTORY', 'COMEDY', 'DRAMA', 'WESTERN', 'ACTION', 'BIOGRAPHY', 'DRAMA', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'DRAMA', 'ACTION', 'ADVENTURE', 'SCI-FI', 'ACTION', 'ADVENTURE', 'DRAMA', 'DRAMA', 'MYSTERY', 'WAR', 'HORROR', 'SCI-FI', 'COMEDY', 'DRAMA', 'CRIME', 'DRAMA', 'HISTORY', 'MYSTERY', 'ROMANCE', 'THRILLER', 'DRAMA', 'FANTASY', 'HORROR', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'CRIME', 'DRAMA', 'COMEDY', 'CRIME', 'DRAMA', 'DRAMA', 'COMEDY', 'DRAMA', 'ROMANCE', 'ACTION', 'ADVENTURE', 'FANTASY', 'COMEDY', 'CRIME', 'COMEDY', 'MUSICAL', 'ROMANCE', 'CRIME', 'DRAMA', 'CRIME', 'DRAMA', 'THRILLER', 'DRAMA', 'CRIME', 'DRAMA', 'ADVENTURE', 'MYSTERY', 'THRILLER', 'DRAMA', 'SCI-FI', 'CRIME', 'MYSTERY', 'THRILLER', 'COMEDY', 'ROMANCE', 'ADVENTURE', 'BIOGRAPHY', 'DRAMA', 'ANIMATION', 'ACTION', 'ADVENTURE', 'DRAMA', 'DRAMA']

# %%
# initialize a null list
unique_list = []
     
# traverse for all elements
for x in list_newnew:
    # check if exists in unique_list or not
    if x not in unique_list:
        unique_list.append(x)
    
print(unique_list)
# Out:
# ['DRAMA', 'CRIME', 'ACTION', 'ADVENTURE', 'BIOGRAPHY', 'HISTORY', 'SCI-FI', 'WESTERN', 'ROMANCE', 'FANTASY', 'COMEDY', 'MUSIC', 'THRILLER', 'MYSTERY', 'ANIMATION', 'FAMILY', 'WAR', 'HORROR', 'FILM-NOIR', 'MUSICAL']

# %%
# Get a dictionary with the counts by Genre

occurrences = collections.Counter(list_newnew)
occurrences
# Out:
# Counter({'DRAMA': 69,
#          'CRIME': 24,
#          'ACTION': 25,
#          'ADVENTURE': 24,
#          'BIOGRAPHY': 8,
#          'HISTORY': 3,
#          'SCI-FI': 9,
#          'WESTERN': 3,
#          'ROMANCE': 8,
#          'FANTASY': 7,
#          'COMEDY': 14,
#          'MUSIC': 3,
#          'THRILLER': 13,
#          'MYSTERY': 14,
#          'ANIMATION': 10,
#          'FAMILY': 3,
#          'WAR': 5,
#          'HORROR': 4,
#          'FILM-NOIR': 1,
#          'MUSICAL': 1})

# %%
#transfor the counting of genres to a DataFrame
df_genres_imdb = pd.DataFrame.from_dict(occurrences, orient='index').reset_index()
df_genres_imdb = df_genres_imdb.rename(columns={'index':'Genres IMDB', 0:'count'})
df_genres_imdb = df_genres_imdb.sort_values(by=["count"], ascending=False)
df_genres_imdb
# Out:
#    Genres IMDB  count
# 0        DRAMA     69
# 2       ACTION     25
# 1        CRIME     24
# 3    ADVENTURE     24
# 13     MYSTERY     14
# 10      COMEDY     14
# 12    THRILLER     13
# 14   ANIMATION     10
# 6       SCI-FI      9
# 8      ROMANCE      8
# 4    BIOGRAPHY      8
# 9      FANTASY      7
# 16         WAR      5
# 17      HORROR      4
# 7      WESTERN      3
# 5      HISTORY      3
# 11       MUSIC      3
# 15      FAMILY      3
# 18   FILM-NOIR      1
# 19     MUSICAL      1

# %%
#Transform the genres imdb to capitalize and not upper
df_genres_imdb['Genres IMDB'] = df_genres_imdb['Genres IMDB'].str.capitalize()
df_genres_imdb
# Out:
#    Genres IMDB  count
# 0        Drama     69
# 2       Action     25
# 1        Crime     24
# 3    Adventure     24
# 13     Mystery     14
# 10      Comedy     14
# 12    Thriller     13
# 14   Animation     10
# 6       Sci-fi      9
# 8      Romance      8
# 4    Biography      8
# 9      Fantasy      7
# 16         War      5
# 17      Horror      4
# 7      Western      3
# 5      History      3
# 11       Music      3
# 15      Family      3
# 18   Film-noir      1
# 19     Musical      1

# %%
#we only want the top 3 of the genres
top_genres_imdb = df_genres_imdb.head(3)
top_genres_imdb
# Out:
#   Genres IMDB  count
# 0       Drama     69
# 2      Action     25
# 1       Crime     24

# %%
#Change index so that we can create the graph - it was given an error with this part
top_genres_imdb = top_genres_imdb.set_index('Genres IMDB')
top_genres_imdb
# Out:
#              count
# Genres IMDB
# Drama           69
# Action          25
# Crime           24

# %%
#Chart of Top 3 genres on IMDB

top_genres_imdb.plot(kind='bar')
plt.title('Top 3 genres on IMDB', color = 'red', size = '20')
plt.xticks(rotation=0)
plt.ylabel('Popularity')
plt.show()

# %% [markdown]
# # Future movies - Top Genres

# %%
imdb_future_movies = pd.read_csv("C:\\Users\\beatr\\Documents\\Beatriz\\Ironhack\\Projects\\Final Project - Module 1\\Project-Week-3-Data-Thieves\\your-project\\imdb.csv")
imdb_future_movies
# Out:
#                                         Name  Date Rate    Votes  \
# 0                             No Time to Die  2021  7.6  107,163
# 1                                 The Guilty  2021  6.3   64,375
# 2                  The Many Saints of Newark  2021  6.4   27,145
# 3                Venom: Let There Be Carnage  2021  6.4   30,443
# 4                                       Dune  2021  8.3   84,636
# ...                                      ...   ...  ...      ...
# 6173  The Human Centipede II (Full Sequence)  2011  3.8   37,492
# 6174                        Double Indemnity  1944  8.3  150,448
# 6175      Before the Devil Knows You're Dead  2007  7.3  100,668
# 6176                              Queen Bees  2021  6.0      887
# 6177                              Death Race  2008  6.3  203,578
#
#                             Genre Duration  Type Certificate Episodes  \
# 0     Action, Adventure, Thriller     163   Film       PG-13        -
# 1          Crime, Drama, Thriller      90   Film           R        -
# 2                    Crime, Drama     120   Film           R        -
# 3       Action, Adventure, Sci-Fi      97   Film       PG-13        -
# 4        Action, Adventure, Drama     155   Film       PG-13        -
# ...                           ...      ...   ...         ...      ...
# 6173                       Horror      91   Film   Not Rated        -
# 6174      Crime, Drama, Film-Noir     107   Film      Passed        -
# 6175       Crime, Drama, Thriller     117   Film           R        -
# 6176       Comedy, Drama, Romance     100   Film       PG-13        -
# 6177     Action, Sci-Fi, Thriller     105   Film           R        -
#
#         Nudity  Violence Profanity   Alcohol Frightening
# 0         Mild  Moderate      Mild      Mild    Moderate
# 1         None      None    Severe      None    Moderate
# 2     Moderate    Severe    Severe  Moderate    Moderate
# 3         None  Moderate  Moderate      Mild    Moderate
# 4         None  Moderate      None      Mild    Moderate
# ...        ...       ...       ...       ...         ...
# 6173    Severe    Severe    Severe      Mild      Severe
# 6174      None      Mild      None      Mild        Mild
# 6175    Severe  Moderate    Severe    Severe      Severe
# 6176      None      None      Mild  Moderate        None
# 6177      Mild    Severe    Severe      Mild    Moderate
#
# [6178 rows x 14 columns]

# %%
#Clean the IMDB date from non-future movies
imdb_future_movies = imdb_future_movies.drop_duplicates(subset=['Name'])
imdb_future_movies = imdb_future_movies[imdb_future_movies["Type"] == "Film"]
imdb_future_movies = imdb_future_movies[imdb_future_movies["Rate"] == "No Rate"]
imdb_future_movies = imdb_future_movies[imdb_future_movies["Date"] >= 2022]
imdb_future_movies

#imdb_future_movies.to_excel("Check future movies.xlsx")
# Out:
#                                    Name  Date     Rate     Votes  \
# 143                              Scream  2022  No Rate  No Votes
# 153                          The Batman  2022  No Rate  No Votes
# 227                       Hocus Pocus 2  2022  No Rate  No Votes
# 295                             The 355  2022  No Rate  No Votes
# 331                        Knives Out 2  2022  No Rate  No Votes
# ...                                 ...   ...      ...       ...
# 4560           Minions: The Rise of Gru  2022  No Rate  No Votes
# 4570           Shazam! Fury of the Gods  2023  No Rate  No Votes
# 4721  Ant-Man and the Wasp: Quantumania  2023  No Rate  No Votes
# 4789                        Turning Red  2022  No Rate  No Votes
# 4798                               BROS  2022  No Rate  No Votes
#
#                              Genre Duration  Type Certificate Episodes  \
# 143      Horror, Mystery, Thriller     120   Film        None        -
# 153           Action, Crime, Drama     None  Film        None        -
# 227        Comedy, Family, Fantasy     None  Film        None        -
# 295               Action, Thriller     None  Film       PG-13        -
# 331           Comedy, Crime, Drama     None  Film        None        -
# ...                            ...      ...   ...         ...      ...
# 4560  Animation, Adventure, Comedy      90   Film          PG        -
# 4570     Action, Adventure, Comedy     None  Film        None        -
# 4721     Action, Adventure, Comedy     None  Film        None        -
# 4789  Animation, Adventure, Comedy     None  Film        None        -
# 4798               Comedy, Romance     None  Film        None        -
#
#        Nudity Violence Profanity  Alcohol Frightening
# 143   No Rate  No Rate   No Rate  No Rate     No Rate
# 153   No Rate  No Rate   No Rate  No Rate     No Rate
# 227   No Rate  No Rate   No Rate  No Rate     No Rate
# 295   No Rate  No Rate   No Rate  No Rate     No Rate
# 331   No Rate  No Rate   No Rate  No Rate     No Rate
# ...       ...      ...       ...      ...         ...
# 4560  No Rate  No Rate   No Rate  No Rate     No Rate
# 4570  No Rate  No Rate   No Rate  No Rate     No Rate
# 4721  No Rate  No Rate   No Rate  No Rate     No Rate
# 4789  No Rate  No Rate   No Rate  No Rate     No Rate
# 4798  No Rate  No Rate   No Rate  No Rate     No Rate
#
# [68 rows x 14 columns]

# %%
#cleaning the columns that are not relevant
imdb_future_movies.drop(columns = ["Rate", "Votes", "Duration", "Type", "Certificate", "Episodes", "Nudity", "Violence", "Profanity", "Alcohol", "Frightening"])
# Out:
#                                    Name  Date                         Genre
# 143                              Scream  2022     Horror, Mystery, Thriller
# 153                          The Batman  2022          Action, Crime, Drama
# 227                       Hocus Pocus 2  2022       Comedy, Family, Fantasy
# 295                             The 355  2022              Action, Thriller
# 331                        Knives Out 2  2022          Comedy, Crime, Drama
# ...                                 ...   ...                           ...
# 4560           Minions: The Rise of Gru  2022  Animation, Adventure, Comedy
# 4570           Shazam! Fury of the Gods  2023     Action, Adventure, Comedy
# 4721  Ant-Man and the Wasp: Quantumania  2023     Action, Adventure, Comedy
# 4789                        Turning Red  2022  Animation, Adventure, Comedy
# 4798                               BROS  2022               Comedy, Romance
#
# [68 rows x 3 columns]

# %%
imdb_future_movies["Genre"]

list_genres_imdb_future =[] 

for item in imdb_future_movies["Genre"]:
    list_genres_imdb_future.append(item)

list_new_future = []

for element in list_genres_imdb_future:
    #print(type(element))
    element = element.split(",")
    #print(element)
    list_new_future.append(element)
    
list_newnew_future = [word.upper().strip() for element in list_new_future for word in element]

#get the list with all genres and separe them for 1 item in the list being one genre
print(list_newnew_future)
# Out:
# ['HORROR', 'MYSTERY', 'THRILLER', 'ACTION', 'CRIME', 'DRAMA', 'COMEDY', 'FAMILY', 'FANTASY', 'ACTION', 'THRILLER', 'COMEDY', 'CRIME', 'DRAMA', 'ACTION', 'ADVENTURE', 'SCI-FI', 'ACTION', 'ADVENTURE', 'FANTASY', 'ACTION', 'DRAMA', 'ACTION', 'ADVENTURE', 'THRILLER', 'ACTION', 'ADVENTURE', 'HORROR', 'THRILLER', 'ACTION', 'ADVENTURE', 'FANTASY', 'ACTION', 'CRIME', 'THRILLER', 'ACTION', 'ADVENTURE', 'SCI-FI', 'ACTION', 'ADVENTURE', 'ACTION', 'ADVENTURE', 'SCI-FI', 'CRIME', 'DRAMA', 'MYSTERY', 'ADVENTURE', 'FAMILY', 'FANTASY', 'ACTION', 'ADVENTURE', 'DRAMA', 'CRIME', 'DRAMA', 'HORROR', 'ACTION', 'FANTASY', 'SCI-FI', 'ACTION', 'THRILLER', 'ACTION', 'ADVENTURE', 'DRAMA', 'DRAMA', 'COMEDY', 'DRAMA', 'SPORT', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'BIOGRAPHY', 'DRAMA', 'ROMANCE', 'ACTION', 'THRILLER', 'ACTION', 'ADVENTURE', 'DRAMA', 'BIOGRAPHY', 'DRAMA', 'HISTORY', 'ADVENTURE', 'COMEDY', 'FAMILY', 'ACTION', 'ADVENTURE', 'FANTASY', 'ADVENTURE', 'FAMILY', 'FANTASY', 'ACTION', 'ADVENTURE', 'COMEDY', 'DRAMA', 'WAR', 'HORROR', 'ACTION', 'ADVENTURE', 'FANTASY', 'ACTION', 'CRIME', 'DRAMA', 'DRAMA', 'HISTORY', 'ACTION', 'ADVENTURE', 'FANTASY', 'DRAMA', 'ROMANCE', 'ANIMATION', 'DRAMA', 'FAMILY', 'ACTION', 'COMEDY', 'DRAMA', 'FANTASY', 'HORROR', 'THRILLER', 'ACTION', 'COMEDY', 'ROMANCE', 'THRILLER', 'ACTION', 'ACTION', 'ADVENTURE', 'COMEDY', 'ACTION', 'ADVENTURE', 'COMEDY', 'ACTION', 'THRILLER', 'ACTION', 'ADVENTURE', 'DRAMA', 'ACTION', 'ADVENTURE', 'SCI-FI', 'ACTION', 'DRAMA', 'FANTASY', 'COMEDY', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'DRAMA', 'COMEDY', 'MUSIC', 'ROMANCE', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'ANIMATION', 'ACTION', 'ADVENTURE', 'ACTION', 'COMEDY', 'CRIME', 'COMEDY', 'ROMANCE', 'ACTION', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'ACTION', 'ADVENTURE', 'COMEDY', 'ACTION', 'ADVENTURE', 'COMEDY', 'ANIMATION', 'ADVENTURE', 'COMEDY', 'COMEDY', 'ROMANCE']

# %%
# initialize a null list
unique_list_future = []
     
# traverse for all elements
for x in list_newnew_future:
    # check if exists in unique_list or not
    if x not in unique_list_future:
        unique_list_future.append(x)
    
print(unique_list_future)
# Out:
# ['HORROR', 'MYSTERY', 'THRILLER', 'ACTION', 'CRIME', 'DRAMA', 'COMEDY', 'FAMILY', 'FANTASY', 'ADVENTURE', 'SCI-FI', 'SPORT', 'ANIMATION', 'BIOGRAPHY', 'ROMANCE', 'HISTORY', 'WAR', 'MUSIC']

# %%
# Get a dictionary with the counts by Genre

occurrences2 = collections.Counter(list_newnew_future)
occurrences2
# Out:
# Counter({'HORROR': 5,
#          'MYSTERY': 2,
#          'THRILLER': 10,
#          'ACTION': 37,
#          'CRIME': 7,
#          'DRAMA': 21,
#          'COMEDY': 22,
#          'FAMILY': 5,
#          'FANTASY': 11,
#          'ADVENTURE': 31,
#          'SCI-FI': 5,
#          'SPORT': 1,
#          'ANIMATION': 8,
#          'BIOGRAPHY': 2,
#          'ROMANCE': 6,
#          'HISTORY': 2,
#          'WAR': 1,
#          'MUSIC': 1})

# %%
#transfor the counting of genres to a DataFrame
df_genres_imdb_future = pd.DataFrame.from_dict(occurrences2, orient='index').reset_index()
df_genres_imdb_future = df_genres_imdb_future.rename(columns={'index':'Genres for future movies', 0:'count'})
df_genres_imdb_future = df_genres_imdb_future.sort_values(by=["count"], ascending=False)
df_genres_imdb_future
# Out:
#    Genres for future movies  count
# 3                    ACTION     37
# 9                 ADVENTURE     31
# 6                    COMEDY     22
# 5                     DRAMA     21
# 8                   FANTASY     11
# 2                  THRILLER     10
# 12                ANIMATION      8
# 4                     CRIME      7
# 14                  ROMANCE      6
# 10                   SCI-FI      5
# 0                    HORROR      5
# 7                    FAMILY      5
# 1                   MYSTERY      2
# 13                BIOGRAPHY      2
# 15                  HISTORY      2
# 11                    SPORT      1
# 16                      WAR      1
# 17                    MUSIC      1

# %%
#Transform the genres imdb to capitalize and not upper
df_genres_imdb_future['Genres for future movies'] = df_genres_imdb_future['Genres for future movies'].str.capitalize()
df_genres_imdb_future
# Out:
#    Genres for future movies  count
# 3                    Action     37
# 9                 Adventure     31
# 6                    Comedy     22
# 5                     Drama     21
# 8                   Fantasy     11
# 2                  Thriller     10
# 12                Animation      8
# 4                     Crime      7
# 14                  Romance      6
# 10                   Sci-fi      5
# 0                    Horror      5
# 7                    Family      5
# 1                   Mystery      2
# 13                Biography      2
# 15                  History      2
# 11                    Sport      1
# 16                      War      1
# 17                    Music      1

# %%
#we only want the top 5 of genres of the future movies
top_genres_imdb_future = df_genres_imdb_future.head(5)
top_genres_imdb_future
# Out:
#   Genres for future movies  count
# 3                   Action     37
# 9                Adventure     31
# 6                   Comedy     22
# 5                    Drama     21
# 8                  Fantasy     11

# %%
#Change index so that we can create the graph - it was given an error with this part
top_genres_imdb_future = top_genres_imdb_future.set_index('Genres for future movies')
top_genres_imdb_future
# Out:
#                           count
# Genres for future movies
# Action                       37
# Adventure                    31
# Comedy                       22
# Drama                        21
# Fantasy                      11

# %%
#Chart of Top 5 genres of Future Movies

top_genres_imdb_future.plot(kind='bar')
plt.title('Top 5 genres for future movies under IMDB', color = 'red', size = '20')
plt.xticks(rotation=0)
plt.ylabel('Popularity')
plt.show()

#Conclusion:
#The reality is the want to

# %% [markdown]
# # Top of the Certificates of top100 IMDB movies

# %%
# To take a look into certificates we will take data from imdb dataframe column 'Certificate' and put it in the list
TopImdb["Certificate"]
certificates_imdb =[] 
for item in TopImdb["Certificate"]:
    certificates_imdb.append(item)
certificates_imdb
# Out:
# ['R',
#  'R',
#  'R',
#  'PG-13',
#  'Approved',
#  'PG-13',
#  'R',
#  'R',
#  'PG-13',
#  'PG-13',
#  'R',
#  'PG-13',
#  'R',
#  'R',
#  'PG-13',
#  'PG',
#  'None',
#  'R',
#  'R',
#  'TV-MA',
#  'R',
#  'R',
#  'PG',
#  'Not Rated',
#  'Not Rated',
#  'PG',
#  'R',
#  'R',
#  'R',
#  'PG-13',
#  'PG',
#  'PG-13',
#  'R',
#  'R',
#  'R',
#  'PG-13',
#  '(Banned)',
#  'G',
#  'R',
#  'R',
#  'R',
#  'PG',
#  'R',
#  'PG-13',
#  'PG',
#  'R',
#  'Not Rated',
#  'R',
#  'PG',
#  'PG',
#  'R',
#  'Approved',
#  'G',
#  'R',
#  'R',
#  'PG-13',
#  'Passed',
#  'PG',
#  'Not Rated',
#  'PG',
#  'Approved',
#  'R',
#  'PG-13',
#  'R',
#  'TV-PG',
#  'R',
#  'PG-13',
#  'PG',
#  'R',
#  'Not Rated',
#  'PG',
#  'R',
#  'PG-13',
#  'PG-13',
#  'R',
#  'R',
#  'PG-13',
#  'M',
#  'PG',
#  'Not Rated',
#  'G',
#  'Approved',
#  'PG',
#  'PG-13',
#  'Approved',
#  'PG',
#  'R',
#  'G',
#  'R',
#  'R',
#  'Unrated',
#  'R',
#  'Approved',
#  'Not Rated',
#  'Passed',
#  'R',
#  'Approved',
#  'None',
#  'PG-13',
#  'R']

# %%
# Count the certicicates in imdb top 100
import collections
certificate_freq = collections.Counter(certificates_imdb)
certificate_freq
# Out:
# Counter({'R': 40,
#          'PG-13': 18,
#          'Approved': 7,
#          'PG': 15,
#          'None': 2,
#          'TV-MA': 1,
#          'Not Rated': 7,
#          '(Banned)': 1,
#          'G': 4,
#          'Passed': 2,
#          'TV-PG': 1,
#          'M': 1,
#          'Unrated': 1})

# %%
cert_items = certificate_freq.items()
cert_list = list(cert_items)
certificate_imdb = pd.DataFrame(cert_list, columns = ['Certificate', 'Popularity']).sort_values(by=['Popularity'], ascending=False)
certificate_imdb = certificate_imdb.head(3)

# %%
# Checking top 3 certificates
certificate_imdb = certificate_imdb.set_index('Certificate')
certificate_imdb.plot(kind='bar')
plt.title('Top 3 Certificates from viewers', color = 'red', size = '20')
plt.xticks(rotation=0)
plt.ylabel('Popularity')
plt.show()
